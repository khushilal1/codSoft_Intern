# %% [markdown]
# # Task 1 of CODSOFT INTERNSHIP PROGRAM

# %%
#IMPORT LIBRARAY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading data
df=pd.read_csv('iris.csv')

# %%
#shape
df.shape
# Out:
# (150, 5)

# %%
#sample
df.sample(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 24           4.8          3.4           1.9          0.2      Iris-setosa
# 36           5.5          3.5           1.3          0.2      Iris-setosa
# 64           5.6          2.9           3.6          1.3  Iris-versicolor
# 19           5.1          3.8           1.5          0.3      Iris-setosa
# 46           5.1          3.8           1.6          0.2      Iris-setosa

# %%
#checking null value
df.isnull().sum()
#there is no any null value
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.columns
#it give the name of columns in dataset
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#getting the short pverview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species']=df['species'].str[5:]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # visulization

# %% [markdown]
# ## feature en\gineering

# %% [markdown]
# # univariate analysis

# %%
# sns.countplot(df['sepal_length'],gap=.3)
df['petal_width'].unique().sum()
# Out:
# 30.099999999999998

# %%
sns.countplot(df['species'])
plt.show()

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#PIE CHART
plt.pie(df['species'].value_counts(),labels=['setosa','virginica','versicolor'],autopct='%.2f%%')
plt.show()

# %%
#box plot

col=['sepal_length','sepal_width','petal_length','petal_width']

for fea in col:
    sns.boxplot(df[fea])
    plt.show()

# %% [markdown]
# # bivariate anlysis

# %% [markdown]
# ## numerica vs numerical

# %%
# scatterplot
sns.scatterplot(data=df,x='sepal_length',y='sepal_width',legend='auto')
plt.show()

# %%
# scatterplot
sns.scatterplot(data=df,x='petal_length',y='petal_width')
plt.show()

# %% [markdown]
# ## numerical vs categoirical

# %%
for fe in col:
    sns.barplot(data=df,x='species',y=fea)
    plt.show()

# %% [markdown]
# # multivraiate analysis

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=df,x='sepal_length',y='sepal_width',hue='species')
plt.show()

# %% [markdown]
#  observation:the sepal lengh of       satosa flower is 4.3 to 5.8,the sepal lengh of versicolor flower is 4.9 to 7 and the sepal lengh of      verginica flower is 4.9 to 7.9

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df,x='petal_width',y='petal_width',hue='species')
plt.show()

# %% [markdown]
#  observation:the petal_lengh of       satosa flower is .1 to .6,the petal_width of versicolor flower is 1 to 1.8 and the sepal lengh of verginica flower is 1.4 to 2.5

# %%
sns.pairplot(data=df)
plt.show()

# %% [markdown]
# # preprocessing

# %%
# from sklearn.preprocessing import LabelEncoder

# %%
# le=LabelEncoder()

# %%
# df['species']=le.fit_transform(df['species'])

# %%
#separation of independent and dependent variable
X=df.iloc[:,:-1]
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
#train test split
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=10)

# %% [markdown]
# # logistics algo

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
precision_score(y_test,y_pred,average=None)
# Out:
# array([1., 1., 1.])

# %% [markdown]
# # ridge classifier

# %%
from sklearn.linear_model import RidgeClassifier

# %%
rc=RidgeClassifier()

# %%
rc.fit(X_train,y_train)
# Out:
# RidgeClassifier()

# %%
y_pred=rc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8333333333333334

# %%
from sklearn.svm import SVC

# %%
sc=SVC()

# %%
sc.fit(X_train,y_train)
# Out:
# SVC()

# %%
y_pred=sc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# # random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# # selection of algo

# %%
# logistics regression is working very well,so i choose this algo for this dataset

# %%
import pickle

# %%
with open('model.pkl','wb') as file:
    pickle.dump(rc,file)

# %%
with open('data.pkl','wb') as files:
    pickle.dump(df,files)
